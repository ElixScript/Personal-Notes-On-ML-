# %% [markdown]
# # Model Selection Notes

# %% [markdown]
# ## what is R squared ?
# R-squared (R2) is defined as a number that tells you how well the independent variable(s) in a statistical model explain the variation in the dependent variable. It ranges from 0 to 1, where 1 indicates a perfect fit of the model to the data.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Membaca dan menampilkan gambar
img = mpimg.imread("C:/Users/ACER/Pictures/Screenshots/Screenshot 2024-08-16 060437.png")
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ## R squared vs adjusted R squared ?
# R squared indicates how well the model explains the overall data, but it doesn't account for the complexity of the model.
# Adjusted R-squared provides a more accurate picture of the model's quality by taking into account the number of variables in the model, making it more reliable when selecting the appropriate model, especially when there are many independent variables.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Membaca dan menampilkan gambar
img = mpimg.imread("C:/Users/ACER/Pictures/Screenshots/Screenshot 2024-08-16 060453.png")
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ## what are pros and cons of each model ?-
#
# **Regression**
#
# | Regression Model           | Pros                                                                                 | Cons                                                                                                 |
# |----------------------------|--------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------|
# | **Linear Regression**       | Works on any size of dataset, gives information about relevance of features          | The Linear Regression Assumptions                                                                    |
# | **Polynomial Regression**   | Works on any size of dataset, works very well on non-linear problems                 | Need to choose the right polynomial degree for a good bias/variance tradeoff                          |
# | **SVR**                     | Easily adaptable, works very well on non-linear problems, not biased by outliers     | Compulsory to apply feature scaling, not well known, more difficult to understand                    |
# | **Decision Tree Regression**| Interpretability, no need for feature scaling, works on both linear/nonlinear problems | Poor results on too small datasets, overfitting can easily occur                                     |
# | **Random Forest Regression**| Powerful and accurate, good performance on many problems, including non-linear        | No interpretability, overfitting can easily occur, need to choose the number of trees                 |
#
# ---
